# %%
import pandas as pd

# %%
df = pd.read_excel("TippecanoeDay1Quals.xlsm")
print(df)
# Out:
#     scouter  eventCode matchLevel  matchNumber robot  teamNumber    as at  au  \
# 0    WS      2022incol  qm         1            r3    4926        [44]  Y  2
# 1    JIH     2022incol  qm         1            b2    4982        [29]  Y  0
# 2    S.G.    2022incol  qm         1            r1    135         [44]  Y  2
# 3    CH      2022incol  qm         1            r2    4926        [44]  Y  2
# 4    RK      2022incol  qm         1            b3    8564        [55]  N  0
# 5    KG      2022incol  qm         1            b1    8564        [17]  Y  0
# 6    S.G.    2022incol  qm         2            r1    461         [19]  Y  2
# 7    JIH     2022incol  qm         2            b2    3176        [18]  Y  1
# 8    RK      2022incol  qm         2            b3    7657        [54]  N  0
# 9    SGG     2022incol  qm         2            r3    1646        [44]  Y  0
# 10   CH      2022incol  qm         2            r2    5188        [44]  N  0
# ...

# %%
pd.isnull(df)
# Out:
# False

# %%
print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 print(df.to_string())
#
# AttributeError: 'dict' object has no attribute 'to_string'

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
print(df)
# Out:
# {'Control':     scouter  eventCode matchLevel  matchNumber robot  teamNumber    as at  au  \
# 0    WS      2022incol  qm         1            r3    4926        [44]  Y  2
# 1    JIH     2022incol  qm         1            b2    4982        [29]  Y  0
# 2    S.G.    2022incol  qm         1            r1    135         [44]  Y  2
# 3    CH      2022incol  qm         1            r2    4926        [44]  Y  2
# 4    RK      2022incol  qm         1            b3    8564        [55]  N  0
# 5    KG      2022incol  qm         1            b1    8564        [17]  Y  0
# 6    S.G.    2022incol  qm         2            r1    461         [19]  Y  2
# 7    JIH     2022incol  qm         2            b2    3176        [18]  Y  1
# 8    RK      2022incol  qm         2            b3    7657        [54]  N  0
# 9    SGG     2022incol  qm         2            r3    1646        [44]  Y  0
# 10   CH      2022incol  qm         2            r2    5188        [44]  N  0
# ...

# %%
print(df)
# Out:
# {'Control':     scouter  eventCode matchLevel  matchNumber robot  teamNumber    as at  au  \
# 0    WS      2022incol  qm         1            r3    4926        [44]  Y  2
# 1    JIH     2022incol  qm         1            b2    4982        [29]  Y  0
# 2    S.G.    2022incol  qm         1            r1    135         [44]  Y  2
# 3    CH      2022incol  qm         1            r2    4926        [44]  Y  2
# 4    RK      2022incol  qm         1            b3    8564        [55]  N  0
# 5    KG      2022incol  qm         1            b1    8564        [17]  Y  0
# 6    S.G.    2022incol  qm         2            r1    461         [19]  Y  2
# 7    JIH     2022incol  qm         2            b2    3176        [18]  Y  1
# 8    RK      2022incol  qm         2            b3    7657        [54]  N  0
# 9    SGG     2022incol  qm         2            r3    1646        [44]  Y  0
# 10   CH      2022incol  qm         2            r2    5188        [44]  N  0
# ...

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
df.keys()
# Out:
# Index(['scouter', 'eventCode', 'matchLevel', 'matchNumber', 'robot',
#        'teamNumber', 'as', 'at', 'au', 'al', 'ac', 'tu', 'tl', 'tm', 'tn',
#        'wd', 'cl', 'ss', 'c', 'be', 'cn', 'ds', 'dr', 'd', 'to', 'cf', 'co',
#        'Column28', 'Column29', 'Column30', 'Column31', 'Column32', 'Column33',
#        'Column34', 'Column35', 'Column36', 'Column37', 'Column38', 'Column39',
#        'Column40', 'Column41'],
#       dtype='object')

# %%
df.iloc[0:3,:]
# Out:
#   scouter  eventCode matchLevel  matchNumber robot  teamNumber    as at  au  \
# 0  WS      2022incol  qm         1            r3    4926        [44]  Y  2
# 1  JIH     2022incol  qm         1            b2    4982        [29]  Y  0
# 2  S.G.    2022incol  qm         1            r1    135         [44]  Y  2
#
#    al ac  tu  tl  tm  tn wd cl              ss  c be  cn ds dr  d to cf  \
# 0  0   Y  10  0   3   0   N  g  [57,8,6,33,16]  2  N  3   x  x  N  N  N
# 1  0   N  0   0   0   0   N  x  NaN             2  N  3   a  a  N  N  N
# 2  0   N  2   0   2   0   Y  x  [53,44,54]      2  Y  3   a  x  N  N  N
#
#                      co  Column28  Column29  Column30  Column31  Column32  \
# 0  NaN                  NaN       NaN       NaN       NaN       NaN
# 1  No intake or shooter NaN       NaN       NaN       NaN       NaN
# 2  NaN                  NaN       NaN       NaN       NaN       NaN
#
#    Column33  Column34  Column35  Column36  Column37  Column38  Column39  \
# ...

# %%
df.isnull()
# Out:
#      scouter  eventCode  matchLevel  matchNumber  robot  teamNumber     as  \
# 0    False    False      False       False        False  False       False
# 1    False    False      False       False        False  False       False
# 2    False    False      False       False        False  False       False
# 3    False    False      False       False        False  False       False
# 4    False    False      False       False        False  False       False
# 5    False    False      False       False        False  False       False
# 6    False    False      False       False        False  False       False
# 7    False    False      False       False        False  False       False
# 8    False    False      False       False        False  False       False
# 9    False    False      False       False        False  False       False
# 10   False    False      False       False        False  False       False
# ...

# %%
cl = df.loc[:,["cl"]]
cl.isnull().sum()
# Out:
# cl    30
# dtype: int64

# %%
cltemp = cl
cltemp = cltemp.dropna()
cltemp.isnull()
# Out:
#         cl
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   False
# 12   False
# 13   False
# 14   False
# 15   False
# 16   False
# 17   False
# 18   False
# 19   False
# 20   False
# 21   False
# 22   False
# 23   False
# 24   False
# 25   False
# 26   False
# 27   False
# 28   False
# 29   False
# 30   False
# 31   False
# 32   False
# 33   False
# 34   False
# 35   False
# 36   False
# 37   False
# 38   False
# 39   False
# 40   False
# 41   False
# 42   False
# 43   False
# 44   False
# 45   False
# 46   False
# 48   False
# 49   False
# 50   False
# 51   False
# 52   False
# 53   False
# 54   False
# 55   False
# 56   False
# 57   False
# 59   False
# 60   False
# 61   False
# 62   False
# 63   False
# 64   False
# 65   False
# 66   False
# 67   False
# 68   False
# 69   False
# 70   False
# 71   False
# 72   False
# 73   False
# 74   False
# 76   False
# 77   False
# ...

# %%
clreplace = cl
clreplace = clreplace.fillna({'cl':'N'})
clreplace
# Out:
#     cl
# 0    g
# 1    x
# 2    x
# 3    g
# 4    g
# 5    x
# 6    x
# 7    g
# 8    b
# 9    x
# 10   g
# 11   x
# 12   x
# 13   x
# 14   g
# 15   g
# 16   x
# 17   g
# 18   g
# 19   g
# 20   g
# 21   t
# 22   x
# 23   b
# 24   x
# 25   g
# 26   g
# 27   x
# 28   g
# 29   g
# 30   g
# 31   t
# 32   g
# 33   g
# 34   x
# 35   x
# 36   g
# 37   x
# 38   g
# 39   x
# 40   x
# 41   g
# 42   b
# 43   x
# 44   g
# 45   x
# 46   x
# 47   N
# 48   g
# 49   x
# 50   x
# 51   x
# 52   g
# 53   g
# 54   t
# 55   b
# 56   g
# 57   x
# 58   N
# 59   g
# 60   b
# 61   g
# 62   g
# 63   g
# 64   t
# 65   g
# 66   x
# 67   g
# 68   t
# 69   g
# 70   b
# 71   g
# 72   x
# 73   g
# 74   x
# 75   N
# 76   x
# 77   g
# 78   g
# 79   x
# 80   x
# 81   g
# 82   g
# 83   N
# 84   x
# 85   b
# 86   g
# 87   x
# 88   g
# 89   x
# 90   g
# 91   t
# 92   g
# 93   g
# 94   g
# 95   x
# 96   g
# 97   N
# 98   b
# 99   g
# 100  x
# 101  g
# 102  x
# 103  g
# 104  g
# 105  g
# 106  g
# 107  g
# 108  g
# 109  g
# ...

# %%
clcase = cl
#clcase = clcase['cl'].str.upper()
#clcase = clcase['cl'].str.lower()
clcase = clcase['cl'].str.title()
clcase
# Out:
# 0      G
# 1      X
# 2      X
# 3      G
# 4      G
# 5      X
# 6      X
# 7      G
# 8      B
# 9      X
# 10     G
# 11     X
# 12     X
# 13     X
# 14     G
# 15     G
# 16     X
# 17     G
# 18     G
# 19     G
# 20     G
# 21     T
# 22     X
# 23     B
# 24     X
# 25     G
# 26     G
# 27     X
# 28     G
# 29     G
# 30     G
# 31     T
# 32     G
# 33     G
# 34     X
# 35     X
# 36     G
# 37     X
# 38     G
# 39     X
# 40     X
# 41     G
# 42     B
# 43     X
# 44     G
# 45     X
# 46     X
# 47     NaN
# 48     G
# 49     X
# 50     X
# 51     X
# 52     G
# 53     G
# 54     T
# 55     B
# 56     G
# 57     X
# 58     NaN
# 59     G
# 60     B
# 61     G
# 62     G
# 63     G
# 64     T
# 65     G
# 66     X
# 67     G
# 68     T
# 69     G
# 70     B
# 71     G
# 72     X
# 73     G
# 74     X
# 75     NaN
# 76     X
# 77     G
# 78     G
# 79     X
# 80     X
# 81     G
# 82     G
# 83     NaN
# 84     X
# 85     B
# 86     G
# 87     X
# 88     G
# 89     X
# ...
