# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("TippecanoeDay1Quals.xlsm")
print(df)
# Out:
#     scouter  eventCode matchLevel  matchNumber robot  teamNumber    as at  au  \
# 0    WS      2022incol  qm         1            r3    4926        [44]  Y  2
# 1    JIH     2022incol  qm         1            b2    4982        [29]  Y  0
# 2    S.G.    2022incol  qm         1            r1    135         [44]  Y  2
# 3    CH      2022incol  qm         1            r2    4926        [44]  Y  2
# 4    RK      2022incol  qm         1            b3    8564        [55]  N  0
# 5    KG      2022incol  qm         1            b1    8564        [17]  Y  0
# 6    S.G.    2022incol  qm         2            r1    461         [19]  Y  2
# 7    JIH     2022incol  qm         2            b2    3176        [18]  Y  1
# 8    RK      2022incol  qm         2            b3    7657        [54]  N  0
# 9    SGG     2022incol  qm         2            r3    1646        [44]  Y  0
# 10   CH      2022incol  qm         2            r2    5188        [44]  N  0
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
print(df)
# Out:
#     scouter  eventCode matchLevel  matchNumber robot  teamNumber    as at  au  \
# 0    WS      2022incol  qm         1            r3    4926        [44]  Y  2
# 1    JIH     2022incol  qm         1            b2    4982        [29]  Y  0
# 2    S.G.    2022incol  qm         1            r1    135         [44]  Y  2
# 3    CH      2022incol  qm         1            r2    4926        [44]  Y  2
# 4    RK      2022incol  qm         1            b3    8564        [55]  N  0
# 5    KG      2022incol  qm         1            b1    8564        [17]  Y  0
# 6    S.G.    2022incol  qm         2            r1    461         [19]  Y  2
# 7    JIH     2022incol  qm         2            b2    3176        [18]  Y  1
# 8    RK      2022incol  qm         2            b3    7657        [54]  N  0
# 9    SGG     2022incol  qm         2            r3    1646        [44]  Y  0
# 10   CH      2022incol  qm         2            r2    5188        [44]  N  0
# ...

# %%
tuh = df.iloc[:,[5,11]]
print(len(tuh.index))
print(tuh)
# Out:
# 440
#      teamNumber  tu
# 0    4926        10
# 1    4982        0
# 2    135         2
# 3    4926        7
# 4    8564        0
# 5    8564        0
# 6    461         5
# 7    3176        12
# 8    7657        0
# 9    1646        0
# 10   5188        0
# 11   7457        0
# 12   2171        1
# 13   2171        2
# 14   1018        0
# 15   3936        0
# 16   1741        0
# 17   292         7
# 18   5484        4
# 19   2867        0
# 20   1529        0
# 21   1555        1
# 22   4485        0
# 23   4272        2
# 24   6721        0
# 25   3147        3
# 26   7477        0
# 27   7198        0
# 28   5402        3
# 29   5010        4
# 30   868         6
# 31   7617        5
# 32   1747        0
# 33   1501        10
# 34   3865        0
# 35   7657        6
# 36   292         6
# 37   3936        0
# 38   3494        4
# 39   234         5
# 40   8103        0
# 41   829         0
# 42   3176        8
# 43   461         4
# 44   4926        14
# 45   2867        0
# ...

# %%
idxlen = len(tuh.index)
tuh_temp = pd.DataFrame(columns=['teamNumber','tu'])
for idx in
# Out:
#   Cell In [34], line 3
#     for idx in
#                ^
# SyntaxError: invalid syntax

# %%
a = tuh.groupby('teamNumber').sum()
print(a)
# Out:
#              tu
# teamNumber
# 71          19
# 135         36
# 234         57
# 292         79
# 461         42
# 829         53
# 868         57
# 1018        0
# 1080        0
# 1501        64
# 1529        18
# 1555        1
# 1646        0
# 1648        0
# 1741        0
# 1747        12
# 2171        29
# 2197        0
# 2867        0
# 3147        33
# 3176        99
# 3494        68
# 3865        0
# 3936        0
# 4272        50
# 4485        0
# 4657        0
# 4926        96
# 4976        5
# 4982        0
# 5010        17
# 5188        25
# 5402        23
# 5484        64
# 5767        0
# 6721        0
# 7198        54
# 7427        0
# 7457        130
# 7477        0
# 7617        75
# 7657        6
# 8103        3
# 8544        0
# 8564        0
# 8742        4

# %%
freq = a.tu.value_counts()
sortFreq = freq.sort_index()
sortFreq2 = sortFreq[1,-1]
sortFreq2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [43], line 3
#       1 freq = a.tu.value_counts()
#       2 sortFreq = freq.sort_index()
# ----> 3 sortFreq2 = sortFreq[1,-1]
#       4 sortFreq2
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:984, in Series.__getitem__(self, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
# --> 984 return self._get_with(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:999, in Series._get_with(self, key)
#     994     raise TypeError(
#     995         "Indexing a Series with DataFrame is not "
#     996         "supported, use the appropriate DataFrame column"
#     997     )
#     998 elif isinstance(key, tuple):
# --> 999     return self._get_values_tuple(key)
# ...

# %%
sortFreq.plot(kind='bar',color='purple')
# Out:
# <AxesSubplot:>

# %%
a.describe()
# Out:
#                tu
# count  46.000000
# mean   26.500000
# std    33.455609
# min    0.000000
# 25%    0.000000
# 50%    9.000000
# 75%    52.250000
# max    130.000000
